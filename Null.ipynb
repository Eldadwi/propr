# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data = pd.read_excel('Desktop/Proprep Usage report.xlsx',sheet_name='Sheet1')

# %%
data
# Out:
#      Signup page                           Email               User name  \
# 0          lp-v3              maztaz35@gmail.com             Maria Smith
# 1     free-trial                 ycw8@kent.ac.uk           Wee Yong Chun
# 2        sign-up         alina.talib@hotmail.com                   alina
# 3        sign-up              ex21105@qmul.ac.uk  Mohamad Fadi Abou Swid
# 4        sign-up  hannahrichards2003@yahoo.co.uk         Hannah Richards
# ..           ...                             ...                     ...
# 497  freshers-v5        ayousuf005020@icloud.com            Abdul yousuf
# 498  freshers-v5           squirem@cardiff.ac.uk                 Matthew
# 499  freshers-v5         carab2009@hotmail.co.uk                    Cara
# 500          NaN                             NaN                     NaN
# 501          NaN                             NaN                     NaN
#
#                     Institution name                     Program name  \
# ...

# %%
df=data.drop(data.index[[500,501]])
df
# Out:
#      Signup page                           Email               User name  \
# 0          lp-v3              maztaz35@gmail.com             Maria Smith
# 1     free-trial                 ycw8@kent.ac.uk           Wee Yong Chun
# 2        sign-up         alina.talib@hotmail.com                   alina
# 3        sign-up              ex21105@qmul.ac.uk  Mohamad Fadi Abou Swid
# 4        sign-up  hannahrichards2003@yahoo.co.uk         Hannah Richards
# ..           ...                             ...                     ...
# 495  freshers-v5         babyray08isme@gmail.com               ALI PASHA
# 496  freshers-v5        ayousuf005020@icloud.com            Abdul yousuf
# 497  freshers-v5        ayousuf005020@icloud.com            Abdul yousuf
# 498  freshers-v5           squirem@cardiff.ac.uk                 Matthew
# 499  freshers-v5         carab2009@hotmail.co.uk                    Cara
#
#                     Institution name                     Program name  \
# ...

# %%
print('Is there any data missing?', df.isnull().values.any())
# Out:
# Is there any data missing? True

# %%
df.isnull()
# Out:
#      Signup page  Email  User name  Institution name  Program name  \
# 0          False  False      False             False         False
# 1          False  False      False             False         False
# 2          False  False      False             False         False
# 3          False  False      False             False         False
# 4          False  False      False             False         False
# ..           ...    ...        ...               ...           ...
# 495        False  False      False             False         False
# 496        False  False      False             False         False
# 497        False  False      False             False         False
# 498        False  False      False             False         False
# 499        False  False      False             False         False
#
#      Course name  Chapter name  % Usage <BR>Chapter  \
# 0          False         False                False
# 1          False         False                False
# ...

# %%
sns.heatmap(df.isnull(),cmap='YlGnBu',yticklabels=False)
# Out:
# <AxesSubplot:>

# %%
df.isnull().sum()
# Out:
# Signup page                       17
# Email                              0
# User name                          0
# Institution name                   0
# Program name                       0
# Course name                        0
# Chapter name                       0
# % Usage <BR>Chapter                0
# Chapter duration<br>(hh:mm:ss)     0
# Last time Watched                  0
# Device                            17
# dtype: int64

# %%
np.where(df['Signup page'].isnull() == True)[0]+2
# Out:
# array([ 60,  62,  89, 101, 112, 113, 144, 166, 217, 266, 331, 347, 367,
#        372, 386, 409, 413], dtype=int64)

# %%
np.where(df['Device'].isnull() == True)[0]+2
# Out:
# array([ 60,  62,  89, 101, 112, 113, 144, 166, 217, 266, 331, 347, 367,
#        372, 386, 409, 413], dtype=int64)
